# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
books = pd.read_csv('Books.csv')
users = pd.read_csv('Users.csv')
ratings = pd.read_csv('Ratings.csv')

# %% [markdown]
# # EDA

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
print(books.shape)
print(users.shape)
print(ratings.shape)
# Out:
# (271360, 8)
# (278858, 3)
# (1149780, 3)

# %%
books.isnull().sum()
# Very Minimal missing values
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
users.isnull().sum()
# Age has around 50 % of Missing values
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
ratings.isnull().sum()
# No missing values
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# np.int64(0)

# %%
users.duplicated().sum()
# Out:
# np.int64(0)

# %%
ratings.duplicated().sum()
# Out:
# np.int64(0)

# %%
# No Duplicates in any of the data frame

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271358 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278858 entries, 0 to 278857
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   User-ID   278858 non-null  int64
#  1   Location  278858 non-null  object
#  2   Age       168096 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.4+ MB

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1149780 non-null  int64
#  1   ISBN         1149780 non-null  object
#  2   Book-Rating  1149780 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 26.3+ MB

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
users.describe()
# Out:
#             User-ID            Age
# count  278858.00000  168096.000000
# mean   139429.50000      34.751434
# std     80499.51502      14.428097
# min         1.00000       0.000000
# 25%     69715.25000      24.000000
# 50%    139429.50000      32.000000
# 75%    209143.75000      44.000000
# max    278858.00000     244.000000

# %%
users['Location'].value_counts()
# Out:
# Location
# london, england, united kingdom                  2506
# toronto, ontario, canada                         2250
# sydney, new south wales, australia               1744
# melbourne, victoria, australia                   1708
# portland, oregon, usa                            1629
#                                                  ...
# gneisenaustr. 3, nordrhein-westfalen, germany       1
# -, bayern, germany                                  1
# bouchegouf, guelma, algeria                         1
# indiana and philadelphia, pennsylvania, usa         1
# tacoma, washington, united kingdom                  1
# Name: count, Length: 57339, dtype: int64

# %%
users['Location'].nunique()
# Out:
# 57339

# %%
# Visualizing top 50 Locations that gave review
plt.figure(figsize=(20, 20))
sns.countplot(users['Location'], order=pd.value_counts(users['Location']).iloc[:50].index)
# Out:
# <Axes: xlabel='count', ylabel='Location'>

# %%
sns.boxplot(x = users['Age']) # Age contains unrealistic values
# Out:
# <Axes: xlabel='Age'>

# %%
# The age columns first of all has null values and also it contains Unrealistic information like Maximum age is 244!
# also minimum is 0 meaning a new born child has given a review so unrealistic information in age column

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
books.describe()
# Out:
#               ISBN      Book-Title      Book-Author  Year-Of-Publication  \
# count       271360          271360           271358               271360
# unique      271360          242135           102022                  202
# top     0195153448  Selected Poems  Agatha Christie                 2002
# freq             1              27              632                13903
#
#         Publisher                                        Image-URL-S  \
# count      271358                                             271360
# unique      16807                                             271044
# top     Harlequin  http://images.amazon.com/images/P/185326119X.0...
# freq         7535                                                  2
#
#                                               Image-URL-M  \
# count                                              271360
# unique                                             271044
# top     http://images.amazon.com/images/P/185326119X.0...
# ...

# %%
ratings.describe()
# Out:
#             User-ID   Book-Rating
# count  1.149780e+06  1.149780e+06
# mean   1.403864e+05  2.866950e+00
# std    8.056228e+04  3.854184e+00
# min    2.000000e+00  0.000000e+00
# 25%    7.034500e+04  0.000000e+00
# 50%    1.410100e+05  0.000000e+00
# 75%    2.110280e+05  7.000000e+00
# max    2.788540e+05  1.000000e+01

# %%
# min rating is from 0 to 10

# %%
sns.countplot(x = ratings['Book-Rating'])
# Out:
# <Axes: xlabel='Book-Rating', ylabel='count'>

# %% [markdown]
# # Popularity Based Recommendation

# %%
# Unlike how many companies use some internal Formula for Popularity, in my projects case i will follow a simpler approach which can be 
# changed depending on the data and Business Logic
# The approach will be that i will show only the Top Average rated Books where the number of ratings is greater than say 200 or 250
# This is Because A book with rating 8.5 with 300 review contains more confidence than a book with 9 rating and only 1 or 2 reviews

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
# First of all we will merge the 2 data frame on the basis of ISBN column

# %%
ratings_with_name = ratings.merge(books,on='ISBN')

# %%
ratings_with_name.shape
# Out:
# (1031136, 10)

# %%
ratings_with_name.head()
# Out:
#    User-ID        ISBN  Book-Rating  \
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6
#
#                                           Book-Title      Book-Author  \
# 0                               Flesh Tones: A Novel       M. J. Rose
# 1                                   Rites of Passage       Judith Rae
# 2                                       The Notebook  Nicholas Sparks
# 3                                     Help!: Level 1    Philip Prowse
# 4  The Amsterdam Connection : Level 4 (Cambridge ...      Sue Leather
#
#   Year-Of-Publication                   Publisher  \
# 0                2002            Ballantine Books
# 1                2001                      Heinle
# 2                1996                Warner Books
# 3                1999  Cambridge University Press
# 4                2001  Cambridge University Press
#
# ...

# %%
# Now that we have merged the 2 dataframes now i need to calculate the number of ratings using groupby and count

# %%
num_rating_df = ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()

# %%
num_rating_df.shape
# Out:
# (241071, 2)

# %%
# reset_index() converts pandas series to data frame

# %%
num_rating_df.head() # I need to rename the Book-Rating to Number if rating
# Out:
#                                           Book-Title  Book-Rating
# 0   A Light in the Storm: The Civil War Diary of ...            4
# 1                              Always Have Popsicles            1
# 2               Apple Magic (The Collector's series)            1
# 3   Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4   Beyond IBM: Leadership Marketing and Finance ...            1

# %%
num_rating_df = num_rating_df.rename(columns={'Book-Rating' : 'num_ratings'})

# %%
num_rating_df.head()
# Out:
#                                           Book-Title  num_ratings
# 0   A Light in the Storm: The Civil War Diary of ...            4
# 1                              Always Have Popsicles            1
# 2               Apple Magic (The Collector's series)            1
# 3   Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4   Beyond IBM: Leadership Marketing and Finance ...            1

# %%
avg_rating_df = ratings_with_name.groupby('Book-Title')['Book-Rating'].mean().reset_index()

# %%
# The average rating dataframe contains the average rating of a book = (Sum of Rating) / (Total Number of Rating)
avg_rating_df.head()
# Out:
#                                           Book-Title  avg_rating
# 0   A Light in the Storm: The Civil War Diary of ...        2.25
# 1                              Always Have Popsicles        0.00
# 2               Apple Magic (The Collector's series)        0.00
# 3   Ask Lily (Young Women of Faith: Lily Series, ...        8.00
# 4   Beyond IBM: Leadership Marketing and Finance ...        0.00

# %%
avg_rating_df.rename(columns={'Book-Rating' : 'avg_rating'},inplace=True)

# %%
avg_rating_df.head()
# Out:
#                                           Book-Title  avg_rating
# 0   A Light in the Storm: The Civil War Diary of ...        2.25
# 1                              Always Have Popsicles        0.00
# 2               Apple Magic (The Collector's series)        0.00
# 3   Ask Lily (Young Women of Faith: Lily Series, ...        8.00
# 4   Beyond IBM: Leadership Marketing and Finance ...        0.00

# %%
avg_rating_df.shape
# Out:
# (241071, 2)

# %%
 popular_df = num_rating_df.merge(avg_rating_df,on='Book-Title')

# %%
# Now i created a final popular data frame which will have top 50 popular books

# %%
popular_df.head()
# Out:
#                                           Book-Title  num_ratings  avg_rating
# 0   A Light in the Storm: The Civil War Diary of ...            4        2.25
# 1                              Always Have Popsicles            1        0.00
# 2               Apple Magic (The Collector's series)            1        0.00
# 3   Ask Lily (Young Women of Faith: Lily Series, ...            1        8.00
# 4   Beyond IBM: Leadership Marketing and Finance ...            1        0.00

# %%
popular_df[popular_df['num_ratings'] >= 250]
# Out:
#                                                Book-Title  num_ratings  \
# 764                                                  1984          284
# 818                                   1st to Die: A Novel          509
# 1048                                           2nd Chance          356
# 1760                                   A Bend in the Road          346
# 2281    A Child Called \It\": One Child's Courage to S...          265
# ...                                                   ...          ...
# 233850                           White Oleander : A Novel          387
# 233851       White Oleander : A Novel (Oprah's Book Club)          356
# 234740  Wicked: The Life and Times of the Wicked Witch...          326
# 234951                                        Wild Animus         2502
# 240860                                \O\" Is for Outlaw"          269
#
#         avg_rating
# 764       4.454225
# 818       3.575639
# 1048      3.269663
# 1760      3.364162
# ...

# %%
popular_df = popular_df[popular_df['num_ratings'] >= 250].sort_values('avg_rating',ascending=False).head(50)

# %%
popular_df
# Out:
#                                                Book-Title  num_ratings  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 80422        Harry Potter and the Goblet of Fire (Book 4)          387
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)          278
# 80426   Harry Potter and the Order of the Phoenix (Boo...          347
# 80414    Harry Potter and the Chamber of Secrets (Book 2)          556
# 191612  The Hobbit : The Enchanting Prelude to The Lor...          281
# 187377  The Fellowship of the Ring (The Lord of the Ri...          368
# 80445   Harry Potter and the Sorcerer's Stone (Harry P...          575
# 211384     The Two Towers (The Lord of the Rings, Part 2)          260
# 219741                              To Kill a Mockingbird          510
# 183573                                  The Da Vinci Code          898
# 187880                 The Five People You Meet in Heaven          430
# ...

# %%
popular_df.shape
# Out:
# (50, 3)

# %%
popular_df.merge(books,on='Book-Title')
# Out:
#                                             Book-Title  num_ratings  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 1    Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 2    Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 3         Harry Potter and the Goblet of Fire (Book 4)          387
# 4         Harry Potter and the Goblet of Fire (Book 4)          387
# ..                                                 ...          ...
# 191                                  Lord of the Flies          259
# 192                            A Prayer for Owen Meany          413
# 193                            A Prayer for Owen Meany          413
# 194   The Vampire Lestat (Vampire Chronicles, Book II)          301
# 195       White Oleander : A Novel (Oprah's Book Club)          356
#
#      avg_rating        ISBN         Book-Author Year-Of-Publication  \
# 0      5.852804  0439136350       J. K. Rowling                1999
# ...

# %%
#I merged the 2 dataframes because i wanted some information related to the book that i can show it on the webpage 
# we have 196 rows because some book are repeated due to diffrent ISBN numbers

# %%
popular_df.merge(books,on='Book-Title').drop_duplicates('Book-Title')
# Out:
#                                             Book-Title  num_ratings  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 3         Harry Potter and the Goblet of Fire (Book 4)          387
# 5       Harry Potter and the Sorcerer's Stone (Book 1)          278
# 9    Harry Potter and the Order of the Phoenix (Boo...          347
# 13    Harry Potter and the Chamber of Secrets (Book 2)          556
# 16   The Hobbit : The Enchanting Prelude to The Lor...          281
# 17   The Fellowship of the Ring (The Lord of the Ri...          368
# 26   Harry Potter and the Sorcerer's Stone (Harry P...          575
# 28      The Two Towers (The Lord of the Rings, Part 2)          260
# 39                               To Kill a Mockingbird          510
# 47                                   The Da Vinci Code          898
# 53                  The Five People You Meet in Heaven          430
# 55                              The Catcher in the Rye          449
# ...

# %%
popular_df = popular_df.merge(books,on='Book-Title').drop_duplicates('Book-Title')[
    ['Book-Title','Book-Author','Year-Of-Publication','Image-URL-M','num_ratings','avg_rating']]

# %%
popular_df
# Out:
#                                             Book-Title  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)
# 3         Harry Potter and the Goblet of Fire (Book 4)
# 5       Harry Potter and the Sorcerer's Stone (Book 1)
# 9    Harry Potter and the Order of the Phoenix (Boo...
# 13    Harry Potter and the Chamber of Secrets (Book 2)
# 16   The Hobbit : The Enchanting Prelude to The Lor...
# 17   The Fellowship of the Ring (The Lord of the Ri...
# 26   Harry Potter and the Sorcerer's Stone (Harry P...
# 28      The Two Towers (The Lord of the Rings, Part 2)
# 39                               To Kill a Mockingbird
# 47                                   The Da Vinci Code
# 53                  The Five People You Meet in Heaven
# 55                              The Catcher in the Rye
# 62                           The Lovely Bones: A Novel
# 63                                                1984
# 72                            Prodigal Summer: A Novel
# ...

# %%
popular_df.shape
# Out:
# (50, 6)

# %%
popular_df.isnull().sum()
# Out:
# Book-Title             0
# Book-Author            0
# Year-Of-Publication    0
# Image-URL-M            0
# num_ratings            0
# avg_rating             0
# dtype: int64

# %%
popular_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import pickle
pickle.dump(popular_df,open('popular.pkl','wb'))

# %% [markdown]
# # Collaborative Filtering Based Model

# %%
ratings_with_name.head()
# Out:
#    User-ID        ISBN  Book-Rating  \
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6
#
#                                           Book-Title      Book-Author  \
# 0                               Flesh Tones: A Novel       M. J. Rose
# 1                                   Rites of Passage       Judith Rae
# 2                                       The Notebook  Nicholas Sparks
# 3                                     Help!: Level 1    Philip Prowse
# 4  The Amsterdam Connection : Level 4 (Cambridge ...      Sue Leather
#
#   Year-Of-Publication                   Publisher  \
# 0                2002            Ballantine Books
# 1                2001                      Heinle
# 2                1996                Warner Books
# 3                1999  Cambridge University Press
# 4                2001  Cambridge University Press
#
# ...

# %%
# My First approach for colabrative filtering is to create a pivot table that will have books as the indexes and the user id's as the 
# columns. Now i will not only take any users, suring EDA we saw som users who gave mischievous entries in the age. 
#So will only consider
# 'authentic' users who have rated say more than 200 books, this way our recommendation engine will become clean
# also i will use only thoese books which have been rated by 50 or more than 50 people.

# %%
x = ratings_with_name.groupby('User-ID').count()['Book-Rating'] > 200

# %%
authentic_users = x[x].index

# %%
# in the above statement i used boolean indexing x[x] to get all true values from a frame that had True False according to the condition
# > 200 and stored it in authentic users

# %%
ratings_with_name[ratings_with_name['User-ID'].isin (authentic_users)]
# These are the reviews that were made by authentic users
# Out:
#          User-ID        ISBN  Book-Rating  \
# 1150      277427  002542730X           10
# 1151      277427  0026217457            0
# 1152      277427  003008685X            8
# 1153      277427  0030615321            0
# 1154      277427  0060002050            0
# ...          ...         ...          ...
# 1029357   275970  1931868123            0
# 1029358   275970  3411086211           10
# 1029359   275970  3829021860            0
# 1029360   275970  4770019572            0
# 1029361   275970  9626340762            8
#
#                                                 Book-Title  \
# 1150     Politically Correct Bedtime Stories: Modern Ta...
# 1151                    Vegetarian Times Complete Cookbook
# 1152                                              Pioneers
# 1153      Ask for May, Settle for June (A Doonesbury book)
# 1154                     On a Wicked Dawn (Cynster Novels)
# ...                                                    ...
# ...

# %%
filtered_rating = ratings_with_name[ratings_with_name['User-ID'].isin (authentic_users)]

# %%
filtered_rating.head(3)
# Out:
#       User-ID        ISBN  Book-Rating  \
# 1150   277427  002542730X           10
# 1151   277427  0026217457            0
# 1152   277427  003008685X            8
#
#                                              Book-Title  \
# 1150  Politically Correct Bedtime Stories: Modern Ta...
# 1151                 Vegetarian Times Complete Cookbook
# 1152                                           Pioneers
#
#                 Book-Author Year-Of-Publication                  Publisher  \
# 1150      James Finn Garner                1994  John Wiley &amp; Sons Inc
# 1151             Lucy  Moll                1995      John Wiley &amp; Sons
# 1152  James Fenimore Cooper                1974           Thomson Learning
#
#                                             Image-URL-S  \
# 1150  http://images.amazon.com/images/P/002542730X.0...
# 1151  http://images.amazon.com/images/P/0026217457.0...
# 1152  http://images.amazon.com/images/P/003008685X.0...
#
# ...

# %%
filtered_rating.shape
# Out:
# (474007, 10)

# %%
y = filtered_rating.groupby('Book-Title').count()['Book-Rating'] >= 50

# %%
# Now that we have filtered users i will use the same data frame to extract movies

# %%
famous_books = y[y].index # Boolean indexing to get only 'True'

# %%
final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
final_ratings.shape
# Out:
# (58586, 10)

# %%
 final_ratings.isnull().sum()
# Out:
# User-ID                0
# ISBN                   0
# Book-Rating            0
# Book-Title             0
# Book-Author            0
# Year-Of-Publication    0
# Publisher              0
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            0
# dtype: int64

# %%
final_ratings.duplicated().sum()
# Out:
# np.int64(0)

# %%
pt = final_ratings.pivot_table(index = 'Book-Title',columns='User-ID',values = 'Book-Rating')

# %%
#Converting the final rating with authentic user and famous books into a pivot table
pt.shape
# Out:
# (706, 810)

# %%
pt.head()
# Out:
# User-ID              254     2276    2766    2977    3363    4017    4385    \
# Book-Title
# 1984                    9.0     NaN     NaN     NaN     NaN     NaN     NaN
# 1st to Die: A Novel     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2nd Chance              NaN    10.0     NaN     NaN     NaN     NaN     NaN
# 4 Blondes               NaN     NaN     NaN     NaN     NaN     NaN     NaN
# A Bend in the Road      0.0     NaN     7.0     NaN     NaN     NaN     NaN
#
# User-ID              6251    6323    6543    ...  271705  273979  274004  \
# Book-Title                                   ...
# 1984                    NaN     NaN     NaN  ...    10.0     NaN     NaN
# 1st to Die: A Novel     NaN     NaN     9.0  ...     NaN     NaN     NaN
# 2nd Chance              NaN     NaN     0.0  ...     NaN     NaN     NaN
# 4 Blondes               0.0     NaN     NaN  ...     NaN     NaN     NaN
# A Bend in the Road      NaN     NaN     NaN  ...     NaN     0.0     NaN
#
# ...

# %%
pt.fillna(0,inplace=True)

# %%
# Filled up the Nan value bcoz these were the values where user didnt gave any review
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
pt.shape
# Out:
# (706, 810)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_score = cosine_similarity(pt)

# %%
similarity_score.shape
# Similarity of each book wit all other each book
# Out:
# (706, 706)

# %%
def recommend(book_name) : 
    # finding the index of book : 
    index = np.where(pt.index == book_name)[0][0]
    # Calculating the top 5 similar books excluding self.
    similar_items = sorted(list(enumerate(similarity_score[index])),key = lambda x : x[1],reverse=True)[1:6]
    data = []
    # we will have a 2-D array and in each array we will have Name,Author and Poster link
    for i in  similar_items:
        item = []
        temp_df = books[books['Book-Title'] == (pt.index[i[0]])]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))

        data.append(item)
    return data

# %%
np.where(pt.index == '1984')[0][0]
# Out:
# np.int64(0)

# %%
sorted(list(enumerate(similarity_score[0])),key = lambda x : x[1],reverse=True)[1:6]
# Out:
# [(47, np.float64(0.2702651417103732)),
#  (545, np.float64(0.26396193711234966)),
#  (82, np.float64(0.2366937434740099)),
#  (634, np.float64(0.23299389358170397)),
#  (551, np.float64(0.2262639743141286))]

# %%
recommend('1984')
# Out:
# Animal Farm
# The Handmaid's Tale
# Brave New World
# The Vampire Lestat (Vampire Chronicles, Book II)
# The Hours : A Novel

# %%
recommend('Message in a Bottle')
# Out:
# Nights in Rodanthe
# The Mulberry Tree
# A Walk to Remember
# River's End
# Nightmares &amp; Dreamscapes

# %%
recommend('The Notebook')
# Out:
# A Walk to Remember
# The Rescue
# One Door Away from Heaven
# Toxin
# The Five People You Meet in Heaven

# %%
recommend('Animal Farm')
# Out:
# 1984
# Angus, Thongs and Full-Frontal Snogging: Confessions of Georgia Nicolson
# Midnight
# Second Nature
# Call of the Wild

# %%
 books[books['Book-Title'] == '1984'].drop_duplicates('Book-Title')['Book-Title']
# Out:
# 2104    1984
# Name: Book-Title, dtype: object

# %%
recommend('1984')
# Out:
# [['Animal Farm',
#   'George Orwell',
#   'http://images.amazon.com/images/P/0451526341.01.MZZZZZZZ.jpg'],
#  ["The Handmaid's Tale",
#   'Margaret Atwood',
#   'http://images.amazon.com/images/P/0449212602.01.MZZZZZZZ.jpg'],
#  ['Brave New World',
#   'Aldous Huxley',
#   'http://images.amazon.com/images/P/0060809833.01.MZZZZZZZ.jpg'],
#  ['The Vampire Lestat (Vampire Chronicles, Book II)',
#   'ANNE RICE',
#   'http://images.amazon.com/images/P/0345313860.01.MZZZZZZZ.jpg'],
#  ['The Hours : A Novel',
#   'Michael Cunningham',
#   'http://images.amazon.com/images/P/0312243022.01.MZZZZZZZ.jpg']]

# %%
books.shape
# Out:
# (271360, 8)

# %%
pickle.dump(pt,open('pt.pkl','wb'))
pickle.dump(books,open('books.pkl','wb'))
pickle.dump(similarity_score,open('similarity_score.pkl','wb'))
